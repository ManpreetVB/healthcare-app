-- %% [markdown]
-- # [HealthcareDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [HealthcareDB]    Script Date: 2/26/2024 10:02:09 PM ******/
CREATE DATABASE [HealthcareDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'HealthcareDB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\HealthcareDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'HealthcareDB_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\HealthcareDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [HealthcareDB] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [HealthcareDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [HealthcareDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [HealthcareDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [HealthcareDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [HealthcareDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [HealthcareDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [HealthcareDB] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [HealthcareDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [HealthcareDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [HealthcareDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [HealthcareDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [HealthcareDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [HealthcareDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [HealthcareDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [HealthcareDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [HealthcareDB] SET  ENABLE_BROKER 
GO
ALTER DATABASE [HealthcareDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [HealthcareDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [HealthcareDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [HealthcareDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [HealthcareDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [HealthcareDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [HealthcareDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [HealthcareDB] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [HealthcareDB] SET  MULTI_USER 
GO
ALTER DATABASE [HealthcareDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [HealthcareDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [HealthcareDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [HealthcareDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [HealthcareDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [HealthcareDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [HealthcareDB] SET QUERY_STORE = ON
GO
ALTER DATABASE [HealthcareDB] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Appointments]

-- %%
USE [HealthcareDB]
GO

-- %%
/****** Object:  Table [dbo].[Appointments]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Appointments](
	[AppointmentID] [int] IDENTITY(1,1) NOT NULL,
	[PatientID] [int] NULL,
	[EmployeeID] [int] NULL,
	[AppointmentDate] [datetime] NULL,
	[Location] [varchar](1000) NULL,
	[IsActive] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[AppointmentID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Departments]

-- %%
/****** Object:  Table [dbo].[Departments]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Departments](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](100) NULL,
	[Description] [varchar](100) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Employees]

-- %%
/****** Object:  Table [dbo].[Employees]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Employees](
	[EmployeeID] [int] IDENTITY(1,1) NOT NULL,
	[FirstName] [varchar](100) NULL,
	[LastName] [varchar](100) NULL,
	[Position] [varchar](100) NULL,
	[Department] [varchar](100) NULL,
	[HireDate] [date] NULL,
	[Salary] [decimal](10, 2) NULL,
	[IsActive] [int] NULL,
	[Email] [varchar](100) NULL,
	[Password] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[EmployeeID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Hospital]

-- %%
/****** Object:  Table [dbo].[Hospital]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Hospital](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[HospitalName] [varchar](100) NULL,
	[HospitalSpeciality] [varchar](100) NULL,
	[Location] [varchar](100) NULL,
	[IsActive] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Patients]

-- %%
/****** Object:  Table [dbo].[Patients]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Patients](
	[PatientID] [int] IDENTITY(1,1) NOT NULL,
	[FirstName] [varchar](100) NULL,
	[LastName] [varchar](100) NULL,
	[DateOfBirth] [date] NULL,
	[ContactNumber] [varchar](100) NULL,
	[MedicalHistory] [varchar](1000) NULL,
	[Allergies] [varchar](1000) NULL,
	[IsActive] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[PatientID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Appointme__Emplo__5FB337D6]

-- %%
ALTER TABLE [dbo].[Appointments]  WITH CHECK ADD FOREIGN KEY([EmployeeID])
REFERENCES [dbo].[Employees] ([EmployeeID])
GO

-- %% [markdown]
-- # [FK__Appointme__Patie__5EBF139D]

-- %%
ALTER TABLE [dbo].[Appointments]  WITH CHECK ADD FOREIGN KEY([PatientID])
REFERENCES [dbo].[Patients] ([PatientID])
GO

-- %% [markdown]
-- # [dbo].[sp_AddNewPatient]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_AddNewPatient]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_AddNewPatient](@FirstName VARCHAR(100),@LastName VARCHAR(100),@DateOfBirth DATE,@ContactNumber VARCHAR(100),
@MedicalHistory VARCHAR(1000),@Allergies VARCHAR(1000),@IsActive INT)
As
 
 BEGIN
     
	 INSERT INTO Patients(FirstName,LastName,DateOfBirth,ContactNumber,MedicalHistory,Allergies,IsActive)
	 VALUES(@FirstName,@LastName,@DateOfBirth,@ContactNumber,@MedicalHistory,@Allergies,@IsActive);
END
GO

-- %% [markdown]
-- # [dbo].[sp_GetDepartmentsList]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_GetDepartmentsList]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_GetDepartmentsList]
As  
BEGIN
    SELECT * FROM Departments;
END
GO

-- %% [markdown]
-- # [dbo].[sp_ManageAddEmployee]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ManageAddEmployee]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_ManageAddEmployee](@FirstName VARCHAR(100),@LastName VARCHAR(100),@Position VARCHAR(100),@Department VARCHAR(100),
@HireDate DATE,@Salary DECIMAL(10,2),@IsActive INT,@Email VARCHAR (100),@Password VARCHAR(100),@Output_Message VARCHAR(100) OUTPUT)
As
BEGIN
 IF NOT EXISTS(SELECT 1 FROM Employees WHERE FirstName=@FirstName AND LastName=@LastName AND IsActive=1 )
 BEGIN
     INSERT INTO Employees(FirstName,LastName,Position,Department,HireDate,Salary,IsActive,Email,Password )
	 VALUES(@FirstName,@LastName,@Position,@Department,@HireDate,@Salary,1,@Email,@Password )
	 SET @Output_Message = 'Employee added';
END
	 ELSE
	BEGIN
		SET @Output_Message = 'Employee already exists with same Name';
	END
	 END
GO

-- %% [markdown]
-- # [dbo].[sp_ManageDeleteEmployee]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ManageDeleteEmployee]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_ManageDeleteEmployee](@EmployeeID INT=NULL,@Output_Message VARCHAR(100) OUTPUT)
	 As
	
	  BEGIN
	   IF  EXISTS (SELECT 1 FROM Employees WHERE EmployeeID=@EmployeeID  AND IsActive=1)
	 BEGIN
		UPDATE Employees SET IsActive=0 WHERE EmployeeID=@EmployeeID  AND IsActive=1 ;
		SET @Output_Message='Record deleted successfully';
	 END

	 ELSE
	 BEGIN
	    SET @Output_Message='Record does not exist';
	 END
	    
	    
END
GO

-- %% [markdown]
-- # [dbo].[sp_ManageDeleteHospital]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ManageDeleteHospital]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC  [dbo].[sp_ManageDeleteHospital](@ID INT=NULL,@IsActive INT=NULL ,@ActionType VARCHAR(100),@Output_Message VARCHAR(1000) OUTPUT)
As 
BEGIN
	IF @ActionType = 'DELETE'
	BEGIN
	--DELETE FROM  Hospital WHERE ID=@ID AND IsActive=1;
	IF EXISTS (SELECT 1 FROM Hospital WHERE ID=@ID AND IsActive=1)
	  BEGIN
	    UPDATE Hospital SET IsActive=0 WHERE ID=@ID AND IsActive=1;
	    SET @Output_Message='Record deleted successfully';
	  END
	ELSE
	   BEGIN
	     SET @Output_Message='Record does not exist';
       END
END
END
GO

-- %% [markdown]
-- # [dbo].[sp_ManageEmployeeGetById]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ManageEmployeeGetById]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_ManageEmployeeGetById]  (@EmployeeID INT,@Output_Message VARCHAR(100) OUTPUT)
As
BEGIN
IF  EXISTS (SELECT 1 FROM Employees WHERE EmployeeID=@EmployeeID AND IsActive=1)

 BEGIN
		SELECT * FROM Employees  WHERE EmployeeID=@EmployeeID AND IsActive=1;
		SET @Output_Message='Data Available'
	
	 END

     ELSE
      BEGIN
	     SET @Output_Message='Data not Available'
	  END

END
GO

-- %% [markdown]
-- # [dbo].[sp_ManageEmployeeList]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ManageEmployeeList]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_ManageEmployeeList](@Output_Message VARCHAR(100) OUTPUT)
As
BEGIN
 IF  EXISTS (SELECT 1 FROM Employees WHERE IsActive=1)
	 BEGIN
	   SELECT*FROM Employees WHERE IsActive=1;
	   SET @Output_Message='Data Available'
	 END

	 ELSE
	 BEGIN
	   SET @Output_Message='Data not Available'
	 END

END
GO

-- %% [markdown]
-- # [dbo].[sp_ManageEmployeeLogin]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ManageEmployeeLogin]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_ManageEmployeeLogin](@Email VARCHAR(100),@Password VARCHAR(100),@Output_Message VARCHAR(100)OUTPUT)
AS
BEGIN
IF EXISTS(SELECT 1 FROM Employees WHERE Email=@Email AND Password=@Password)
  BEGIN
    SELECT * FROM Employees WHERE Email=@Email AND Password=@Password ;
	SET @Output_Message='Valid Employee';
  END
  ELSE
  BEGIN
     SET @Output_Message='Invalid Employee';
   END
   END
GO

-- %% [markdown]
-- # [dbo].[sp_ManageGetByIdHospital]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ManageGetByIdHospital]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC  [dbo].[sp_ManageGetByIdHospital](@ID INT=NULL,@ActionType VARCHAR(100),@Output_Message VARCHAR(1000) OUTPUT)
As 
BEGIN
	IF @ActionType = 'GETBYID'
	BEGIN
	IF  EXISTS (SELECT 1 FROM Hospital WHERE ID=@ID AND IsActive=1)
	 BEGIN
		SELECT * FROM Hospital WHERE ID=@ID AND IsActive=1;
	    SET @Output_Message='Data Available'
	
	 END

     ELSE
      BEGIN
	     SET @Output_Message='Data not Available'
	  END
END

END
GO

-- %% [markdown]
-- # [dbo].[sp_ManageGetHospital]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ManageGetHospital]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
	CREATE PROC  [dbo].[sp_ManageGetHospital](@ActionType VARCHAR(100),@Output_Message VARCHAR(1000) OUTPUT)
As 
BEGIN
	IF @ActionType = 'GET'
	
	 BEGIN
	  IF  EXISTS (SELECT 1 FROM Hospital WHERE IsActive=1)
	  SELECT * FROM Hospital WHERE IsActive=1;
	   SET @Output_Message='Data Available'
	 END

	 ELSE
	 BEGIN
	   SET @Output_Message='Data not Available'
	 END

	
	END

GO

-- %% [markdown]
-- # [dbo].[sp_ManageHospital]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ManageHospital]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC  [dbo].[sp_ManageHospital](@ID INT=NULL,@HospitalName VARCHAR(100)=NULL,@HospitalSpeciality VARCHAR(100)=NULL,@Location VARCHAR(100)=NULL,
@IsActive INT=NULL ,@ActionType VARCHAR(100),@Output_Message VARCHAR(1000) OUTPUT)
As 
BEGIN
    
	IF @ActionType = 'ADD'
	BEGIN
	   IF NOT EXISTS(SELECT 1 FROM Hospital WHERE HospitalName=@HospitalName AND HospitalSpeciality=@HospitalSpeciality AND Location=@Location AND IsActive=1)
	   BEGIN
	      INSERT INTO Hospital(HospitalName,HospitalSpeciality,Location,IsActive)
	      VALUES(@HospitalName,@HospitalSpeciality,@Location,@IsActive)
	      SET @Output_Message='Record inserted successfully';
	   END
	   ELSE
	      BEGIN
	      SET @Output_Message='Record Already exist';
	      END
	END  
END
GO

-- %% [markdown]
-- # [dbo].[sp_ManageRegistrationEmployee]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ManageRegistrationEmployee]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_ManageRegistrationEmployee](@FirstName VARCHAR(100),@LastName VARCHAR(100),@Position VARCHAR(100),@Department VARCHAR(100),@HireDate DATETIME,
@Salary DECIMAL(10,2),@Email VARCHAR(100),@Password VARCHAR(100),@Output_Message VARCHAR(100) OUTPUT)
AS
BEGIN
  IF NOT EXISTS(SELECT 1 FROM Employees WHERE Email=@Email AND IsActive=1)
   BEGIN
     INSERT INTO Employees(FirstName,LastName,Position,Department,HireDate, Salary,IsActive,Email,Password)
	 VALUES(@FirstName,@LastName,@Position,@Department,@HireDate,@Salary, 1,@Email,@Password);
	 SET @Output_Message ='Employee added';
   END

   ELSE
     BEGIN
	   	 SET @Output_Message ='Employee already exists with same email';

	 END
END	
GO

-- %% [markdown]
-- # [dbo].[sp_ManageUpdateEmployee]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ManageUpdateEmployee]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_ManageUpdateEmployee](@EmployeeID INT,@FirstName VARCHAR(100),@LastName VARCHAR(100),@Position VARCHAR(100),@Department VARCHAR(100),
@Salary DECIMAL(10,2),@IsActive INT,@Email VARCHAR(100),@Password VARCHAR(100),@Output_Message VARCHAR(1000) OUTPUT)
As
BEGIN
IF EXISTS (SELECT 1 FROM Employees WHERE EmployeeID=@EmployeeID AND IsActive=1)
	    BEGIN
		 
		       UPDATE Employees SET FirstName=@FirstName,LastName=@LastName,Position=@Position,Department=@Department,
	           Salary=@Salary ,Email=@Email ,Password=@Password WHERE EmployeeID=@EmployeeID AND IsActive=1;
		       SET @Output_Message='Record Updated successfully';
             END
      
         ELSE
		   BEGIN
		    SET @Output_Message='Record does not exist';
		   END
    END
      
GO

-- %% [markdown]
-- # [dbo].[sp_ManageUpdateHospital]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ManageUpdateHospital]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC  [dbo].[sp_ManageUpdateHospital](@ID INT=NULL,@Location VARCHAR(100)=NULL,@IsActive INT=NULL ,@ActionType VARCHAR(100),
	@Output_Message VARCHAR(1000) OUTPUT)
As 
BEGIN
	IF @ActionType = 'UPDATE'
	BEGIN
	IF EXISTS (SELECT 1 FROM Hospital WHERE ID=@ID AND IsActive=1)
	    BEGIN
		   IF NOT EXISTS(SELECT 1 FROM Hospital WHERE Location=@Location AND IsActive=1 )
		   BEGIN
	         UPDATE Hospital SET Location=@Location
	         WHERE ID=@ID AND IsActive=1;
	         SET @Output_Message='Record Updated successfully';
            END
         ELSE
		   BEGIN
		    SET @Output_Message='Record Already exist';
		   END
       END
      ELSE
	     BEGIN
          SET @Output_Message='Recoerd does not exist';
	     END

END
END
GO

-- %% [markdown]
-- # [dbo].[sp_UpdatePatient]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_UpdatePatient]    Script Date: 2/26/2024 10:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_UpdatePatient](@PatientID INT ,@FirstName VARCHAR(100),@LastName VARCHAR(100),@DateOfBirth DATE,@ContactNumber VARCHAR(100),
@MedicalHistory VARCHAR(1000),@Allergies VARCHAR(1000),@IsActive INT)

As
 BEGIN
   UPDATE Patients SET FirstName=@FirstName,LastName=@LastName,DateOfBirth=@DateOfBirth ,ContactNumber=@ContactNumber,
   MedicalHistory=@MedicalHistory, Allergies=@Allergies,IsActive=@IsActive
   WHERE PatientID=@PatientID;
   END
GO

-- %% [markdown]
-- # [HealthcareDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [HealthcareDB] SET  READ_WRITE 
GO
